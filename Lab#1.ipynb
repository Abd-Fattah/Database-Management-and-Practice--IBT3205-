# %% [markdown]
# <a href="https://colab.research.google.com/github/Abd-Fattah/Database-Management-and-Practice--IBT3205-/blob/main/Lab%231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !cp kaggle.json /Users/Fattakh/kaggle
# !chmod 600 /Users/Fattakh/kaggle/kaggle.json
# !kaggle datasets download -d tarekmuhammed/telecom-customers
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/Users/Fattakh/kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/tarekmuhammed/telecom-customers
# License(s): apache-2.0
# ...
# 100% 172k/172k [00:00<00:00, 673kB/s]
# 100% 172k/172k [00:00<00:00, 672kB/s]

# %%
# !unzip telecom-customers.zip
# Out:
# Archive:  telecom-customers.zip
#   inflating: Telecom Customers Churn.csv

# %%
import pandas as pd
from google.colab import files
from matplotlib import pyplot as plt

files.upload()
# Out:
#      <input type="file" id="files-30258dfc-c090-4da2-9ffb-1e1a2c1ae108" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30258dfc-c090-4da2-9ffb-1e1a2c1ae108">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.read_csv('/content/Telecom Customers Churn.csv')
df = pd.read_csv('/content/Telecom Customers Churn.csv')
pd.read_csv('/content/Telecom Customers Churn.csv')
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !cp my_project ~/content/
# Out:
# cp: -r not specified; omitting directory 'my_project'

# %%
# !pwd
# Out:
# /content

# %%
y = df.loc[:99, "MonthlyCharges"].values
print(x)
x = [i for i in range(0, 100)]
print(y)
# Out:
# [ 29.85  56.95  53.85  42.3   70.7   99.65  89.1   29.75 104.8   56.15
#   49.95  18.95 100.35 103.7  105.5  113.25  20.65 106.7   55.2   90.05
#   39.65  19.8   20.15  59.9   59.6   55.3   99.35  30.2   90.25  64.7
#   96.35  95.5   66.15  20.2   45.25  99.9   69.7   74.8  106.35  97.85
#   49.55  69.2   20.75  79.85  76.2   84.5   49.25  80.65  79.75  64.15
#   90.25  99.1   69.5   80.65  74.85  95.45  99.65 108.45  24.95 107.5
#  100.5   89.9   42.1   54.4   94.4   75.3   78.9   79.2   20.15  79.85
#   49.05  20.4  111.6   24.25  64.5  110.5   55.65  54.65  74.75  25.9
#   79.35  50.55  75.15 103.8   20.15  99.3   62.15  20.65  19.95  33.75
#   82.05  74.7   84.   111.05 100.9   78.95  66.85  21.05  21.    98.5 ]
# [ 29.85  56.95  53.85  42.3   70.7   99.65  89.1   29.75 104.8   56.15
#   49.95  18.95 100.35 103.7  105.5  113.25  20.65 106.7   55.2   90.05
#   39.65  19.8   20.15  59.9   59.6   55.3   99.35  30.2   90.25  64.7
# ...

# %%
fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, y)
plt.title("Sample Visualization", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Sample Visualization')
